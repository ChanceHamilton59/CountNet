# %% [markdown]
# ## Loads needed modules to load and evaluate the pretrained model

# %%
import matplotlib.pyplot as plt
import numpy as np
import os


from ModelUtils import *
from CountNet import *
import pickle

import tensorflow as tf
from tensorflow.keras import layers
from keras.layers.core import Dense
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.models import Model

# %% [markdown]
# # Load Trained Model

# %%
model = tf.keras.models.load_model('Model_EP10_LR001_BS64/SavedModels/DeepModel')
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.

# %% [markdown]
# # Load TestResults from model evaluation

# %%
test_results = getData('Model_EP10_LR001_BS256/RESULTS/TestData/TestResults.obj')
error, accuracy, misses, test_results = evalOnDataset(test_results, model)
# Out:
# Corrected MSE       : 0.0002946375957572186
# Prediction Accuracy : 0.9997053624042428

# %%
fig = makeResultDataHist(misses)
# Out:
# [0 2]

# %%
fig2 = getConMat(test_results)

# %% [markdown]
# ## Load unseen dataset and evaluation

# %%
unseen_data = getData('Datasets/unseenData.obj')

# %%
error, accuracy, misses, test_results = evalOnDataset(unseen_data, model)
# Out:
# Corrected MSE       : 0.2891566265060241
# Prediction Accuracy : 0.7469879518072289

# %%
fig = getConMat(test_results)
